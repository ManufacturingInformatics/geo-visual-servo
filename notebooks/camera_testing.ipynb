# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots

plt.style.use(['science', 'notebook'])

# %%
target_pose_square = np.load('data/target_pose.npz')
target_pose_square.files
# Out:
# ['pose', 'q_vals', 'depth_image']

# %%
target_pose_square['depth_image'].shape
# Out:
# (480, 640)

# %%
plt.figure()
plt.matshow(target_pose_square['depth_image'], cmap=plt.cm.plasma)
plt.show()

# %%
target_pose_multi_hole = np.load('data/target_pose_multi_hole.npz')
target_pose_multi_hole.files
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 target_pose_multi_hole = np.load('data/target_pose_multi_hole.npz')
#       2 target_pose_multi_hole.files
#
# File ~/anaconda3/envs/geo-visual-servo/lib/python3.10/site-packages/numpy/lib/_npyio_impl.py:451, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     449     own_fid = False
#     450 else:
# --> 451     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     452     own_fid = True
#     454 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/target_pose_multi_hole.npz'

# %%
plt.figure()
plt.matshow(target_pose_multi_hole['depth_image'], cmap=plt.cm.plasma)
plt.show()

# %%
initial_pose_square = jnp.load('data/initial_pose_square.npz')
initial_pose_square.files
# Out:
# ['pose', 'q_vals', 'depth_image']

# %%
plt.figure()
plt.matshow(initial_pose_square['depth_image'], cmap=plt.cm.plasma)
plt.show()
